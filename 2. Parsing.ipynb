# %% [markdown]
# # Parsing
# 2025 labs done in Codespaces/Github

# %%
# %pip install beautifulsoup4 requests pandas lxml openpyxl
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/vscode/.local/lib/python3.12/site-packages (4.14.3)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.12/site-packages (2.32.5)
# Requirement already satisfied: pandas in /usr/local/python/3.12.12/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: lxml in /usr/local/python/3.12.12/lib/python3.12/site-packages (6.0.2)
# Requirement already satisfied: openpyxl in /usr/local/python/3.12.12/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/vscode/.local/lib/python3.12/site-packages (from beautifulsoup4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vscode/.local/lib/python3.12/site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.12/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.12/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.12/site-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.12/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.12/lib/python3.12/site-packages (from pandas) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.12/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: et-xmlfile in /usr/local/python/3.12.12/lib/python3.12/site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# для себя:
#
# https://docs.python.org/3/library/concurrent.futures.html

# %% [markdown]
# ## UTILITIES

# %%
BASE_URL = 'http://magnitogorsk-citystar.ru'
FLATS_LIST_URL = BASE_URL + '/realty/prodazha-kvartir/'

def fetch_page(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return BeautifulSoup(response.text, 'lxml')
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

def get_flats_list_pages():
    pages = []
    for i in range(1, 22):
        url = f'{FLATS_LIST_URL}?p={i}'
        soup = fetch_page(url)
        if soup:
            pages.append(soup)
            print(f"Fetched page {i}")
        time.sleep(0.5)  # pause
    return pages

def extract_flats_from_page(soup):
    flats_data = []
    
    table = soup.find('table', {'id': 'tbl_10043'})
    if not table:
        print("No table found on page")
        return flats_data
    
    for tr in table.find_all('tr'):
        tds = tr.find_all('td', recursive=False)
        if len(tds) < 5:  # skip empty
            continue
        
        try:
            flat_id = int(tds[0].input['value'])
            link = tds[4].a['href']
            flats_data.append((flat_id, link))
        except (ValueError, TypeError, KeyError, IndexError) as e:
            print(f"Error parsing row: {e}")
            continue
    
    return flats_data

def extract_flat_details(flat_id, flat_link):
    url = BASE_URL + flat_link
    soup = fetch_page(url)
    
    if not soup:
        return None
    
    details = {}
    div = soup.find('div', 'adv-main-data')
    
    if div:
        # key-value pairs
        keys = [key.get_text(strip=True) for key in div.find_all('td', 'field-title')]
        values = [value.get_text(strip=True).replace('\xa0', ' ') for value in div.find_all('td', 'field')]
        
        # dict
        for key, value in zip(keys, values):
            details[key] = value
        
        # description
        note = div.find('td', 'note')
        if note:
            details['Описание'] = note.get_text(strip=True)
    
    # link id
    details['Ссылка'] = url
    details['ID'] = flat_id
    
    return details

# %% [markdown]
# ## PARSING

# %%
def main_parsing():
    print("start lab parsing")
    
    # listing pages
    pages = get_flats_list_pages()
    
    # all flats data extract
    all_flats_data = []
    for page in pages:
        flats_data = extract_flats_from_page(page)
        all_flats_data.extend(flats_data)
    
    print(f"Found {len(all_flats_data)} flats")
    
    # parallel processing
    all_details = []
    
    # ThreadPoolExecutor
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = []
        for flat_id, flat_link in all_flats_data:
            futures.append(executor.submit(extract_flat_details, flat_id, flat_link))
        
        for future in as_completed(futures):
            result = future.result()
            if result:
                all_details.append(result)
                print(f"Processed {len(all_details)}/{len(all_flats_data)} flats")
            time.sleep(0.3)  # pause
    
    # df
    df = pd.DataFrame(all_details)
    
    # id as index
    if 'ID' in df.columns:
        df = df.set_index('ID')
    
    # autosave
    #df.to_csv('magnitogorsk_parsing.csv', encoding='utf-8-sig')
    #df.to_excel('magnitogorsk_parsing.xlsx')
# Processed 482/486 flats
# Processed 483/486 flats
# Processed 484/486 flats
# Processed 485/486 flats
# Processed 486/486 flats
# done

# %%
df.head(3)
# Out:
#                                                       Цена Этаж  \
# ID
# 23812767  1 560 000р.(65 000р./м2)Подать заявку на ипотеку  1/2
# 23812765  2 770 000р.(63 532р./м2)Подать заявку на ипотеку  1/5
# 23812768  2 080 000р.(65 000р./м2)Подать заявку на ипотеку  1/2
#
#                                     Площадь  Кол-во комнат Этажность дома  \
# ID
# 23812767    общая24 м2,жилая18 м2,кухни5 м2  Однокомнатная              2
# 23812765  общая43,6 м2,жилая30 м2,кухни6 м2  Двухкомнатная              5
# 23812768   общая32 м2,жилая20 м2,кухни12 м2  Однокомнатная              2
#
#                                                    Описание  \
# ID
# 23812767  id:47636. \nУстали от городского шума и суеты?...
# 23812765  id:47626. \nПредставляем вашему вниманию уютну...
# 23812768  id:47637. \nУстали от городского шума и суеты?...
#
#                                                      Ссылка             Адрес  \
# ID
# 23812767  http://magnitogorsk-citystar.ru/realty/prodazh...               NaN
# 23812765  http://magnitogorsk-citystar.ru/realty/prodazh...  Советская, 145/1
# 23812768  http://magnitogorsk-citystar.ru/realty/prodazh...  Ленина пр-т, 214
#
#          Район Состояние квартиры  ...  \
# ID                                 ...
# 23812767   NaN                NaN  ...
# 23812765   NaN                NaN  ...
# 23812768   NaN                NaN  ...
#
#          Районная поликлиника, школы, детские сады, магазины и т. д.  \
# ID
# 23812767                                                NaN
# 23812765                                                NaN
# 23812768                                                NaN
#
#          Год последнего ремонта Окон на Север Окон на Юг Окон на Запад  \
# ID
# 23812767                    NaN           NaN        NaN           NaN
# 23812765                    NaN           NaN        NaN           NaN
# 23812768                    NaN           NaN        NaN           NaN
#
#          Окон на Восток Доступный транспорт Ближайший паркинг  \
# ID
# 23812767            NaN                 NaN               NaN
# 23812765            NaN                 NaN               NaN
# 23812768            NaN                 NaN               NaN
#
#          Микрорайон или ориентир Правоустанавливающие документы
# ID
# 23812767                     NaN                            NaN
# 23812765                     NaN                            NaN
# 23812768                     NaN                            NaN
#
# [3 rows x 31 columns]

# %% [markdown]
# только важное, как вариант только первые столбцы

# %%
new_df = df.iloc[:, :8].copy()
new_df
# Out:
#                                                        Цена  Этаж  \
# ID
# 23812767   1 560 000р.(65 000р./м2)Подать заявку на ипотеку   1/2
# 23812765   2 770 000р.(63 532р./м2)Подать заявку на ипотеку   1/5
# 23812768   2 080 000р.(65 000р./м2)Подать заявку на ипотеку   1/2
# 23812769   2 080 000р.(63 609р./м2)Подать заявку на ипотеку   1/1
# 23812766   1 250 000р.(30 488р./м2)Подать заявку на ипотеку   2/2
# ...                                                     ...   ...
# 15406262   8 000 000р.(76 190р./м2)Подать заявку на ипотеку   4/9
# 16262155   5 500 000р.(84 615р./м2)Подать заявку на ипотеку  1/10
# 16022577   5 560 000р.(76 374р./м2)Подать заявку на ипотеку   6/6
# 14046477   5 000 000р.(74 405р./м2)Подать заявку на ипотеку   1/2
# 15761115  1 950 000р.(108 333р./м2)Подать заявку на ипотеку   2/2
#
#                                      Площадь     Кол-во комнат Этажность дома  \
# ID
# 23812767     общая24 м2,жилая18 м2,кухни5 м2     Однокомнатная              2
# 23812765   общая43,6 м2,жилая30 м2,кухни6 м2     Двухкомнатная              5
# 23812768    общая32 м2,жилая20 м2,кухни12 м2     Однокомнатная              2
# 23812769   общая32,7 м2,жилая30 м2,кухни0 м2               NaN              1
# 23812766     общая41 м2,жилая20 м2,кухни7 м2     Однокомнатная              2
# ...                                      ...               ...            ...
# 15406262   общая105 м2,жилая83 м2,кухни10 м2  Четырехкомнатная              9
# 16262155    общая65 м2,жилая43 м2,кухни12 м2     Двухкомнатная             10
# 16022577   общая72,8 м2,жилая44 м2,кухни8 м2     Трехкомнатная              6
# 14046477  общая67,2 м2,жилая45 м2,кухни12 м2     Трехкомнатная              2
# 15761115     общая18 м2,жилая15 м2,кухни0 м2     Однокомнатная              2
#
#                                                    Описание  \
# ID
# 23812767  id:47636. \nУстали от городского шума и суеты?...
# 23812765  id:47626. \nПредставляем вашему вниманию уютну...
# 23812768  id:47637. \nУстали от городского шума и суеты?...
# 23812769  id:47638. \nПредставьте себе уединённый уголок...
# 23812766  id:47633. \nПродам уютную 1-комнатную квартиру...
# ...                                                     ...
# 15406262  Предлагаю Вашему вниманию четырёхкомнатную ква...
# 16262155  <p>В продаже уютная 2к квартира, в одном из лу...
# 16022577  <p>Для ценителей Ленинского района в продаже у...
# 14046477  Срочно продам уникальную квартиру с дизайнерск...
# 15761115  В эксклюзивной продаже апартаменты в <b>ЖК"КАР...
#
#                                                      Ссылка  \
# ID
# 23812767  http://magnitogorsk-citystar.ru/realty/prodazh...
# 23812765  http://magnitogorsk-citystar.ru/realty/prodazh...
# 23812768  http://magnitogorsk-citystar.ru/realty/prodazh...
# 23812769  http://magnitogorsk-citystar.ru/realty/prodazh...
# 23812766  http://magnitogorsk-citystar.ru/realty/prodazh...
# ...                                                     ...
# 15406262  http://magnitogorsk-citystar.ru/realty/prodazh...
# 16262155  http://magnitogorsk-citystar.ru/realty/prodazh...
# 16022577  http://magnitogorsk-citystar.ru/realty/prodazh...
# 14046477  http://magnitogorsk-citystar.ru/realty/prodazh...
# 15761115  http://magnitogorsk-citystar.ru/realty/prodazh...
#
#                        Адрес
# ID
# 23812767                 NaN
# 23812765    Советская, 145/1
# 23812768    Ленина пр-т, 214
# 23812769   Ленина пр-т, 212б
# 23812766         Садовая, 18
# ...                      ...
# 15406262   Карла Маркса, 185
# 16262155        Жукова, 19/1
# 16022577      Строителей, 57
# 14046477  Западное шоссе, 95
# 15761115       Курортная, 19
#
# [486 rows x 8 columns]

# %%
#df.to_csv('lab_parsing.csv', index=False)
#df.to_excel('lab_parsing.csv', index=False)

# %%
clean_df = new_df.replace({'\u2028': ' ', '\u2029': ' '}, regex=True)
clean_df.to_csv('lab_parsing.csv', index=False, lineterminator='\n')

# %% [markdown]
# Вывод по лабе: получен lab_parsing.csv файл парсингом
