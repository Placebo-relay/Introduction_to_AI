# %% [markdown]
# # API
# 2025 labs done in Codespaces/Github

# %% [markdown]
# original by Grandmaster-reviewer Дуркин Анатолий Альбертович

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.12/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ## DS 5

# %%
url = 'https://api.hh.ru/vacancies'
params = {'text': 'Data Scientist', 'per_page': '5', 'page': '1'}
src = requests.get(url, params=params)
data = src.json()

# %% [markdown]
# Мы указали адрес, откуда получать данные. Здесь взаимодействие происходит не через библиотеку или функции, а при обращении к определенному адресу.
#
# Также мы указываем параметры: должность, которую ищем, сколько вакансий на странице отображать и какую страницу читаем.
#
# А дальше мы просто получаем данные по указанным параметрам и превращаем их в удобный нам формат. В данном случае данные возвращаются нам в формате JSON - очень популярном для общения сервисов в сети - поэтому в таком виде их и обрабатываем.
#
# Посмотрим, что мы получили.

# %%
data
# Out:
# {'items': [{'id': '128921862',
#    'premium': False,
#    'name': 'Project Manager (AI)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False},
#    'salary_range': {'from': 1118,
#     'to': 1615,
#     'currency': 'USD',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'Национальный аэропорт Минск',
#     'building': None,
#     'lat': 53.889263,
#     'lng': 28.034156,
#     'description': None,
#     'raw': 'Минск, Национальный аэропорт Минск',
#     'metro': None,
#     'metro_stations': [],
#     'id': '13721893'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-19T17:50:24+0300',
#    'created_at': '2025-12-19T17:50:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128921862',
#    'show_logo_in_search': None,
#    'show_contacts': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128921862?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128921862',
#    'relations': [],
#    'employer': {'id': '9228941',
#     'name': 'Up pashkevich',
#     'url': 'https://api.hh.ru/employers/9228941',
#     'alternate_url': 'https://hh.ru/employer/9228941',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/7007109.png',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/7007110.png',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/7007111.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9228941',
#     'country_id': 8,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в роли Project Manager от 1,5 лет, включая управление AI/ML-проектами. Подтверждённый опыт ведения полного цикла AI...',
#     'responsibility': 'Координация работы кросс-функциональной команды (ML-инженеры, <highlighttext>data</highlighttext> <highlighttext>scientists</highlighttext>, разработчики). Взаимодействие со стейкхолдерами, управление ожиданиями и коммуникацией. Оптимизация процессов разработки...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128731045',
#    'premium': False,
#    'name': 'Аналитик больших данных/Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'проспект Андропова',
#     'building': '18к3',
#     'lat': 55.694459,
#     'lng': 37.661994,
#     'description': None,
#     'raw': 'Москва, проспект Андропова, 18к3',
#     'metro': {'station_name': 'Технопарк',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.512',
#      'line_id': '2',
#      'lat': 55.695,
#      'lng': 37.664167},
#     'metro_stations': [{'station_name': 'Технопарк',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.512',
#       'line_id': '2',
#       'lat': 55.695,
#       'lng': 37.664167}],
#     'id': '13584024'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-15T07:54:58+0300',
#    'created_at': '2025-12-15T07:54:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128731045',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128731045?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128731045',
#    'relations': [],
#    'employer': {'id': '9368347',
#     'name': 'А ДЕНЬГИ',
#     'url': 'https://api.hh.ru/employers/9368347',
#     'alternate_url': 'https://hh.ru/employer/9368347',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1471066.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7710198.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7710199.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9368347',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Глубокие знания классического ML, теории вероятностей, математической статистики, алгоритмов и структур данных. Знание алгоритмов и структур данных, способность применять в...',
#     'responsibility': 'Разработка ML-моделей для решения бизнес и рисковых задач, тестирование и оценка их качества. Выдвижение гипотез и извлечение ценных инсайтов...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128544099',
#    'premium': False,
#    'name': 'Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-08T17:02:05+0300',
#    'created_at': '2025-12-08T17:02:05+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128544099',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128544099?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128544099',
#    'relations': [],
#    'employer': {'id': '11920587',
#     'name': 'Secunda',
#     'url': 'https://api.hh.ru/employers/11920587',
#     'alternate_url': 'https://hh.ru/employer/11920587',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1412011.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7267704.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7267705.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11920587',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Владение Python и основными библиотеками анализа данных. Знание SQL (оконные функции, оптимизация запросов) и навыки работы с базами данных. ',
#     'responsibility': 'Заниматься построением и поддержкой скоринговых моделей, самостоятельно строить ML-модели (логистическая регрессия, градиентный бустинг, деревья решений) для прогноза дефолтов. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128586832',
#    'premium': False,
#    'name': 'Middle Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '160',
#     'name': 'Алматы',
#     'url': 'https://api.hh.ru/areas/160'},
#    'salary': {'from': 1400000,
#     'to': 1600000,
#     'currency': 'KZT',
#     'gross': False},
#    'salary_range': {'from': 1400000,
#     'to': 1600000,
#     'currency': 'KZT',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': None},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Алматы',
#     'street': 'улица Абиша Кекилбайулы',
#     'building': '139',
#     'lat': 43.205491,
#     'lng': 76.889338,
#     'description': None,
#     'raw': 'Алматы, улица Абиша Кекилбайулы, 139',
#     'metro': None,
#     'metro_stations': [],
#     'id': '16586649'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-09T17:47:04+0300',
#    'created_at': '2025-12-09T17:47:04+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128586832',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128586832?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128586832',
#    'relations': [],
#    'employer': {'id': '10780378',
#     'name': 'Teez',
#     'url': 'https://api.hh.ru/employers/10780378',
#     'alternate_url': 'https://hh.ru/employer/10780378',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/6731961.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/6731962.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/6731963.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10780378',
#     'country_id': 3,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Быстро решили, быстро сделали, быстро поехали дальше. Опыт работы в <highlighttext>Data</highlighttext> Science от 2-х лет. Умение работать с SQL...',
#     'responsibility': 'Развивать самостоятельно систему поисковой выдачи для маркетплейса на базе ML-технологий (ранжирование, персонализация, векторный поиск и др). Создавать решения, упрощающие...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128147364',
#    'premium': False,
#    'name': 'Исследователь/Research Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Шлюзовая набережная',
#     'building': '4',
#     'lat': 55.731551,
#     'lng': 37.644261,
#     'description': None,
#     'raw': 'Москва, Шлюзовая набережная, 4',
#     'metro': {'station_name': 'Павелецкая',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.101',
#      'line_id': '2',
#      'lat': 55.729741,
#      'lng': 37.638693},
#     'metro_stations': [{'station_name': 'Павелецкая',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.101',
#       'line_id': '2',
#       'lat': 55.729741,
#       'lng': 37.638693},
#      {'station_name': 'Павелецкая',
#       'line_name': 'Кольцевая',
#       'station_id': '5.102',
#       'line_id': '5',
#       'lat': 55.731414,
#       'lng': 37.636294}],
#     'id': '2307678'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-27T17:20:09+0300',
#    'created_at': '2025-11-27T17:20:09+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128147364',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128147364?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128147364',
#    'relations': [],
#    'employer': {'id': '3491569',
#     'name': 'Криптонит',
#     'url': 'https://api.hh.ru/employers/3491569',
#     'alternate_url': 'https://hh.ru/employer/3491569',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/4016742.png',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/4016743.png',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/4016744.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3491569',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Ученая степень, законченная аспирантура, наличие научных публикаций/докладов. Знание и уверенное владение минимум двумя языками программирования, знание современных Unix-style...',
#     'responsibility': 'Ведение исследовательских работ в области математики, Computer Science, электроники, телекоммуникаций и сетей, смежных областях.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '79',
#      'name': 'Научный специалист, исследователь'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None}],
#  'found': 387,
#  'pages': 78,
#  'page': 1,
#  'per_page': 5,
#  'clusters': None,
#  'arguments': None,
#  'fixes': None,
#  'suggests': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&items_on_page=5&page=1&text=Data+Scientist'}

# %% [markdown]
# Мы получили вакансии, как и запрашивали. Вот только теперь они лежат в словарях, которые нам предстоит разобрать. Описанипе всех тегов вы можете найти в документации.
#
# Итак, посмотрим, какие ключи есть в нашем словаре.

# %%
data.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'page', 'per_page', 'clusters', 'arguments', 'fixes', 'suggests', 'alternate_url'])

# %% [markdown]
# Здесь указаны параметры, которые мы передавали (относительно страниц и числа вакансий на них), а также прочие основные параметры. Но нас интересует только список с вакансиями, он лежит с ключом `items`.

# %%
len(data['items'])
# Out:
# 5

# %% [markdown]
# Тут мы оценили размер списка, лежащего под указанным ключом. В нём действительно 20 элементов, как мы и запрашивали. Посмотрим на первый.

# %%
data['items'][0]
# Out:
# {'id': '128921862',
#  'premium': False,
#  'name': 'Project Manager (AI)',
#  'department': None,
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1002',
#   'name': 'Минск',
#   'url': 'https://api.hh.ru/areas/1002'},
#  'salary': {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False},
#  'salary_range': {'from': 1118,
#   'to': 1615,
#   'currency': 'USD',
#   'gross': False,
#   'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#   'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Минск',
#   'street': 'Национальный аэропорт Минск',
#   'building': None,
#   'lat': 53.889263,
#   'lng': 28.034156,
#   'description': None,
#   'raw': 'Минск, Национальный аэропорт Минск',
#   'metro': None,
#   'metro_stations': [],
#   'id': '13721893'},
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2025-12-19T17:50:24+0300',
#  'created_at': '2025-12-19T17:50:24+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128921862',
#  'show_logo_in_search': None,
#  'show_contacts': True,
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/128921862?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/128921862',
#  'relations': [],
#  'employer': {'id': '9228941',
#   'name': 'Up pashkevich',
#   'url': 'https://api.hh.ru/employers/9228941',
#   'alternate_url': 'https://hh.ru/employer/9228941',
#   'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/7007109.png',
#    '90': 'https://img.hhcdn.ru/employer-logo-round/7007110.png',
#    '240': 'https://img.hhcdn.ru/employer-logo-round/7007111.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9228941',
#   'country_id': 8,
#   'accredited_it_employer': False,
#   'trusted': True},
#  'snippet': {'requirement': 'Опыт в роли Project Manager от 1,5 лет, включая управление AI/ML-проектами. Подтверждённый опыт ведения полного цикла AI...',
#   'responsibility': 'Координация работы кросс-функциональной команды (ML-инженеры, <highlighttext>data</highlighttext> <highlighttext>scientists</highlighttext>, разработчики). Взаимодействие со стейкхолдерами, управление ожиданиями и коммуникацией. Оптимизация процессов разработки...'},
#  'contacts': None,
#  'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'fly_in_fly_out_duration': [],
#  'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#  'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#  'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#  'night_shifts': False,
#  'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#  'accept_incomplete_resumes': False,
#  'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'employment_form': {'id': 'FULL', 'name': 'Полная'},
#  'internship': False,
#  'adv_response_url': None,
#  'is_adv_vacancy': False,
#  'adv_context': None}

# %% [markdown]
# ## Параметры

# %% [markdown]
# Мы видим большое количество параметров, свойств, описание которых (подробное и на русском) есть в документации. Отсюда многое можно взять в нашу таблицу для анализа. Я возьму лишь пару параметров для демонстрации.

# %%
vacancy = data['items'][0]

# %%
vacancy['name']
# Out:
# 'Project Manager (AI)'

# %%
vacancy['id']
# Out:
# '128921862'

# %%
vacancy['salary']
# Out:
# {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False}

# %% [markdown]
# Вот тут могут начинаться первые проблемы. Данных о зарплате может и не быть вовсе, а могут быть неполные. Тут стоит обрабатывать данные аккуратно.
#
# Подберём две вакансии, одну с зарплатой, другую без, и посмотрим разницу.

# %%
# с зарплатой
vacancy_s = [v for v in data['items'] if v['salary']][0]
# без зарплаты
vacancy_w = [v for v in data['items'] if not v['salary']][0]

# %% [markdown]
# Дадите объяснение моим действиям? Если не очень понятно, то пустое значение `None` приравнивается к `False`, поэтому условие выглядит именно так. А как бы сделали вы?

# %%
vacancy_w['salary']

# %% [markdown]
# Тут и правда не указаны зарплаты. Что ж, посмотрим на вторую вакансию.

# %%
vacancy_s['salary']
# Out:
# {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False}

# %% [markdown]
# Внутри не просто число, внутри лежит целый словарь (если что-то пошло не так, выгрузите список вакансий снова или увеличьте размер выгрузки, возможно, в этом нет вакансий с зарплатой). А в нём указаны границы зарплатной вилки, валюта и даже указание, до или после вычета налогов.
#
# Как бы вы поступили с такими данными? Я возьму только одно из значений - нижнюю границу зарплаты. Но это для демонстрации, ваше решение явно будет отличаться.

# %%
vacancy_s['salary']['from']
# Out:
# 1118

# %% [markdown]
# Это всё хорошо, но как же достать это значение, если этого словаря не будет вообще? Конечно, проверить на наличие. Давайте напишем небольшой цикл, пробежав по имеющимся у нас вакансиям.

# %%
for vacancy in data['items']:
    if vacancy['salary']:
        print(vacancy['salary']['from'])
    else:
        print('Не указано')
# Out:
# 1118
# Не указано
# Не указано
# 1400000
# Не указано

# %% [markdown]
# Сможем ли мы сократить это условие? Конечно, воспользуемся тернарным оператором:

# %%
for vacancy in data['items']:
    print(vacancy['salary']['from'] if vacancy['salary'] else 'Не указано')
# Out:
# 1118
# Не указано
# Не указано
# 1400000
# Не указано

# %% [markdown]
# Прекрасно! А главное, кратко и понятно.

# %% [markdown]
# ## Собираем таблицу

# %% [markdown]
# Попробуем создать небольшую таблицу для данных. Я создам совсем небольшую, чтобы посмотреть, как это работает.

# %%
df = pd.DataFrame(columns=['name', 'salary_from'])

for vacancy in data['items']:
    id = vacancy['id']
    name = vacancy['name']
    salary_from = vacancy['salary']['from'] if vacancy['salary'] else None
    df.loc[id] = [name, salary_from]

# %%
df
# Out:
#                                              name salary_from
# 128921862                    Project Manager (AI)        1118
# 128731045  Аналитик больших данных/Data Scientist        None
# 128544099                          Data Scientist        None
# 128586832                   Middle Data Scientist     1400000
# 128147364        Исследователь/Research Scientist        None

# %% [markdown]
# Да, табличка и правда получилась!
#
# Конечно, я оставил для вас самое интересное. Как минимум, примените бритву Оккама - тут слишком много лишних сущностей, можно и короче. А как максимум...

# %% [markdown]
# ## Парсим интересные вакансии

# %% [markdown]
# Как максимум я хочу, чтобы вы собрали большую таблицу по вакансиям и проанализировали её. При этом выберите ту должность, которая интересно лично вам.
#
# Предлагаю такие шаги:
#
# 1. Какие данные из вакансии заслуживают внимания? Что стоит доставать и помещать в таблицу? Уделите особое внимание численным параметрам - с остальными мы пока не особо учились работать.
# 2. Какие данные могут быть проблемными? Где-то могут встречаться пропуски, как в зарплатах, их нужно обработать.
# 3. Как собрать больше вакансий? Больше 100 на странице не получится, а страниц может быть несколько. Надо собрать данные со всех.
# 4. Какой базовый анализ можно провести? Интересно, какие зарплаты предлагают по должностям, в каких городах сколько вакансий, и прочее, прочее, прочее...
#
# Уверен, это не составит большого труда, у вас всё получится!

# %%
import requests, time

def get_vacancies_minimal(text="Data Scientist"):
    url = 'https://api.hh.ru/vacancies'
    results = []
    
    for page in range(5):
        response = requests.get(url, params={
            'text': text,
            'per_page': 100,
            'page': page
        }, headers={'User-Agent': 'TestBot'})
        
        if response.status_code == 200:
            data = response.json()
            if data.get('items'):
                results.extend(data['items'])
                print(f"Page {page}: {len(data['items'])} items")
            else:
                break
        time.sleep(0.3)
    
    print(f"Total: {len(results)} vacancies")
    return results

# %%
my_data = get_vacancies_minimal(text="web")
# Out:
# Page 0: 100 items
# Page 1: 100 items
# Page 2: 100 items
# Page 3: 100 items
# Page 4: 100 items
# Total: 500 vacancies

# %% [markdown]
# # Data scientist Job

# %%
import requests
import time

def get_vacancies():
    url = 'https://api.hh.ru/vacancies'
    jsons_list = []
    
    headers = {'User-Agent': 'TestBot'}
    
    # Data Scientist с хорошей зарплатой, удалённо
    params = {
        'text': 'Data Scientist',
        'per_page': '100',
        'page': 0,
        'only_with_salary': True,
        'schedule': 'remote',
        'salary': 150000,
        'currency': 'RUR',
        'search_field': 'name',
        'order_by': 'salary_desc',
        'experience': 'between3And6',
    }
    

    for num_page in range(5):
        params['page'] = num_page
        
        try:
            src = requests.get(url, params=params, headers=headers, timeout=10)
            
            if src.status_code != 200:
                print(f"Страница {num_page}: Ошибка {src.status_code}")
                break
                
            data = src.json()
            
            if 'items' not in data or not data['items']:
                print(f"Страница {num_page}: больше нет вакансий")
                break
                
            jsons_list.append(data)
            print(f"Страница {num_page+1}: {len(data['items'])} вакансий")
            
            # pause api to fix timeout
            time.sleep(0.3)
            
        except requests.exceptions.Timeout:
            print(f"Страница {num_page}: Таймаут, пропускаем")
            continue
        except Exception as e:
            print(f"Страница {num_page}: Ошибка {type(e).__name__}")
            break
    
    print(f"\nСобрано: {len(jsons_list)} страниц с вакансиями")
    if jsons_list:
        total_vacancies = sum(len(page['items']) for page in jsons_list)
        print(f"Всего вакансий: {total_vacancies}")
        
        # gold_job
        if jsons_list[0]['items']:
            top_vacancy = jsons_list[0]['items'][0]
            salary = top_vacancy.get('salary', {})
            print(f"gold_job: {top_vacancy['name']}")
            print(f"   coin: {salary.get('from', '?')} - {salary.get('to', '?')} {salary.get('currency', 'руб.')}")
            if 'schedule' in top_vacancy:
                print(f"   График: {top_vacancy['schedule'].get('name', '?')}")
    
    return jsons_list

# %%
vacancies = get_vacancies()
# Out:
# Страница 1: 10 вакансий
# Страница 1: больше нет вакансий
#
# Собрано: 1 страниц с вакансиями
# Всего вакансий: 10
# gold_job: Lead Data Scientist (LLM) / Ведущий специалист по данным
#    coin: None - 5000 USD
#    График: Удаленная работа

# %% [markdown]
# # Job Table

# %%
import pandas as pd

data = pd.DataFrame(columns=[
    'title',               # Название
    'salary_min',          # ЗП от
    'salary_max',          # ЗП до  
    'experience',          # Опыт 3-6
    'company',             # Компания
    'location',            # Локация
    'work_schedule',       # График = удаленка
    'remote_type',         # Формат
    'key_requirements',    # Ключевые требования
    'is_trusted_employer', # Проверенный работодатель
    'has_test',            # Тест!
    'url'                  # Ссылка
])

for col in data.columns:
    print(f"  -> {col}")
# Out:
#   -> title
#   -> salary_min
#   -> salary_max
#   -> experience
#   -> company
#   -> location
#   -> work_schedule
#   -> remote_type
#   -> key_requirements
#   -> is_trusted_employer
#   -> has_test
#   -> url

# %%
for page in vacancies:
    if 'items' not in page:
        continue
        
    for vacancy in page['items']:
        row = {
            'title': vacancy.get('name', ''),
            'url': vacancy.get('alternate_url', ''),
        }
        
        salary_data = vacancy.get('salary')
        if salary_data:
            row['salary_min'] = salary_data.get('from')
            row['salary_max'] = salary_data.get('to')
        else:
            row['salary_min'] = None
            row['salary_max'] = None
        
        experience_data = vacancy.get('experience', {})
        row['experience'] = experience_data.get('name', '') if experience_data else ''
        
        employer_data = vacancy.get('employer', {})
        row['company'] = employer_data.get('name', '')
        row['is_trusted_employer'] = employer_data.get('trusted', False)
        
        area_data = vacancy.get('area', {})
        row['location'] = area_data.get('name', '')
        
        schedule_data = vacancy.get('schedule', {})
        row['work_schedule'] = schedule_data.get('name', '')
        
        work_format_data = vacancy.get('work_format', [{}])
        row['remote_type'] = work_format_data[0].get('name', '') if work_format_data else ''
        
        snippet_data = vacancy.get('snippet', {})
        requirements = snippet_data.get('requirement', '')
        row['key_requirements'] = requirements[:150] if requirements else ''
        
        row['has_test'] = vacancy.get('has_test', False)
        
        new_row_df = pd.DataFrame([row])
        data = pd.concat([data, new_row_df], ignore_index=True)

data
# Out:
#                                                title salary_min salary_max  \
# 0  Lead Data Scientist (LLM) / Ведущий специалист...       None       5000
# 1                         Senior ML / Data Scientist       3500       4350
# 2                            Data Scientist (senior)     200000     400000
# 3                            Data Scientist (senior)     200000     400000
# 4                            Data Scientist (senior)     200000     400000
# 5                            Data Scientist (senior)     200000     400000
# 6                            Data Scientist (senior)     200000     400000
# 7                                     Data Scientist       None     300000
# 8                      Data analyst / Data scientist     230000     250000
# 9                                     Data Scientist       None     180000
#
#       experience                   company         location     work_schedule  \
# 0  От 3 до 6 лет                WaveAccess  Санкт-Петербург  Удаленная работа
# 1  От 3 до 6 лет            ПБК Менеджмент            Минск  Удаленная работа
# 2  От 3 до 6 лет  Бюро судебного взыскания           Москва  Удаленная работа
# 3  От 3 до 6 лет  Бюро судебного взыскания           Казань  Удаленная работа
# 4  От 3 до 6 лет  Бюро судебного взыскания  Санкт-Петербург  Удаленная работа
# 5  От 3 до 6 лет  Бюро судебного взыскания     Екатеринбург  Удаленная работа
# 6  От 3 до 6 лет  Бюро судебного взыскания  Нижний Новгород  Удаленная работа
# 7  От 3 до 6 лет               Детский мир           Москва  Удаленная работа
# 8  От 3 до 6 лет                    ROSSKO           Москва  Удаленная работа
# 9  От 3 до 6 лет              Hawking Bros           Москва  Удаленная работа
#
#              remote_type                                   key_requirements  \
# 0               Удалённо  5+ years of commercial experience in <highligh...
# 1               Удалённо  Мы усиливаем команду разработки моделей и ищем...
# 2               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 3               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 4               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 5               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 6               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 7  На месте работодателя  Уверенное владение знаниями о работе и создани...
# 8               Удалённо  Вы умеете выявлять факторы влияния на эффектив...
# 9               Удалённо  Опыт работы с табличными данными и классически...
#
#   is_trusted_employer has_test                              url
# 0                True    False  https://hh.ru/vacancy/128483349
# 1                True    False  https://hh.ru/vacancy/128152732
# 2                True    False  https://hh.ru/vacancy/127981401
# 3                True    False  https://hh.ru/vacancy/128913274
# 4                True    False  https://hh.ru/vacancy/128913275
# 5                True    False  https://hh.ru/vacancy/128913276
# 6                True    False  https://hh.ru/vacancy/128913277
# 7                True     True  https://hh.ru/vacancy/127795453
# 8                True    False  https://hh.ru/vacancy/127307468
# 9                True    False  https://hh.ru/vacancy/128102483

# %%
data.head(1)
# Out:
#                                                title salary_min salary_max  \
# 0  Lead Data Scientist (LLM) / Ведущий специалист...       None       5000
#
#       experience     company         location     work_schedule remote_type  \
# 0  От 3 до 6 лет  WaveAccess  Санкт-Петербург  Удаленная работа    Удалённо
#
#                                     key_requirements is_trusted_employer  \
# 0  5+ years of commercial experience in <highligh...                True
#
#   has_test                              url
# 0    False  https://hh.ru/vacancy/128483349

# %% [markdown]
# Lead Data Scientist (LLM) / Ведущий специалист по данным
#
# до 5 000 $ за месяц
#
# Формат работы: удалённо

# %%
data.iloc[0]['key_requirements']
# Out:
# '5+ years of commercial experience in <highlighttext>data</highlighttext> science or ML engineering. Ability to design the overall approach to solving.'

# %% [markdown]
# Виджет по api.hh.ru

# %%
from IPython.display import IFrame

# url
widget_url = "https://api.hh.ru/widgets/vacancies/employer?employer_id=2251053&locale=RU&links_color=1560b2&border_color=1560b2&title=&show_region=true&professional_role=165"

# widget
IFrame(src=widget_url, width=350, height=250)
