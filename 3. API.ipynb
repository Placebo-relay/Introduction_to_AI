# %% [markdown]
# # API
# 2025 labs

# %% [markdown]
# original by Grandmaster-reviewer Дуркин Анатолий Альбертович

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/python/3.12.12/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/python/3.12.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/python/3.12.12/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 2)) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
import json

# %% [markdown]
# ## DS 5

# %%
url = 'https://api.hh.ru/vacancies'
params = {'text': 'Data Scientist', 'per_page': '5', 'page': '1'}
src = requests.get(url, params=params)
data = src.json()

# %% [markdown]
# Мы указали адрес, откуда получать данные. Здесь взаимодействие происходит не через библиотеку или функции, а при обращении к определенному адресу.
#
# Также мы указываем параметры: должность, которую ищем, сколько вакансий на странице отображать и какую страницу читаем.
#
# А дальше мы просто получаем данные по указанным параметрам и превращаем их в удобный нам формат. В данном случае данные возвращаются нам в формате JSON - очень популярном для общения сервисов в сети - поэтому в таком виде их и обрабатываем.
#
# Посмотрим, что мы получили.

# %%
data
# Out:
# {'items': [{'id': '128921862',
#    'premium': False,
#    'name': 'Project Manager (AI)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1002',
#     'name': 'Минск',
#     'url': 'https://api.hh.ru/areas/1002'},
#    'salary': {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False},
#    'salary_range': {'from': 1118,
#     'to': 1615,
#     'currency': 'USD',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Минск',
#     'street': 'Национальный аэропорт Минск',
#     'building': None,
#     'lat': 53.889263,
#     'lng': 28.034156,
#     'description': None,
#     'raw': 'Минск, Национальный аэропорт Минск',
#     'metro': None,
#     'metro_stations': [],
#     'id': '13721893'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-19T17:50:24+0300',
#    'created_at': '2025-12-19T17:50:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128921862',
#    'show_logo_in_search': None,
#    'show_contacts': True,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128921862?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128921862',
#    'relations': [],
#    'employer': {'id': '9228941',
#     'name': 'Up pashkevich',
#     'url': 'https://api.hh.ru/employers/9228941',
#     'alternate_url': 'https://hh.ru/employer/9228941',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/7007109.png',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/7007110.png',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/7007111.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9228941',
#     'country_id': 8,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт в роли Project Manager от 1,5 лет, включая управление AI/ML-проектами. Подтверждённый опыт ведения полного цикла AI...',
#     'responsibility': 'Координация работы кросс-функциональной команды (ML-инженеры, <highlighttext>data</highlighttext> <highlighttext>scientists</highlighttext>, разработчики). Взаимодействие со стейкхолдерами, управление ожиданиями и коммуникацией. Оптимизация процессов разработки...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128731045',
#    'premium': False,
#    'name': 'Аналитик больших данных/Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'проспект Андропова',
#     'building': '18к3',
#     'lat': 55.694459,
#     'lng': 37.661994,
#     'description': None,
#     'raw': 'Москва, проспект Андропова, 18к3',
#     'metro': {'station_name': 'Технопарк',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.512',
#      'line_id': '2',
#      'lat': 55.695,
#      'lng': 37.664167},
#     'metro_stations': [{'station_name': 'Технопарк',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.512',
#       'line_id': '2',
#       'lat': 55.695,
#       'lng': 37.664167}],
#     'id': '13584024'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-15T07:54:58+0300',
#    'created_at': '2025-12-15T07:54:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128731045',
#    'branding': {'type': 'MAKEUP', 'tariff': None},
#    'show_logo_in_search': True,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128731045?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128731045',
#    'relations': [],
#    'employer': {'id': '9368347',
#     'name': 'А ДЕНЬГИ',
#     'url': 'https://api.hh.ru/employers/9368347',
#     'alternate_url': 'https://hh.ru/employer/9368347',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1471066.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7710198.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7710199.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9368347',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Глубокие знания классического ML, теории вероятностей, математической статистики, алгоритмов и структур данных. Знание алгоритмов и структур данных, способность применять в...',
#     'responsibility': 'Разработка ML-моделей для решения бизнес и рисковых задач, тестирование и оценка их качества. Выдвижение гипотез и извлечение ценных инсайтов...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128544099',
#    'premium': False,
#    'name': 'Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-08T17:02:05+0300',
#    'created_at': '2025-12-08T17:02:05+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128544099',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128544099?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128544099',
#    'relations': [],
#    'employer': {'id': '11920587',
#     'name': 'Secunda',
#     'url': 'https://api.hh.ru/employers/11920587',
#     'alternate_url': 'https://hh.ru/employer/11920587',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1412011.png',
#      '90': 'https://img.hhcdn.ru/employer-logo/7267704.png',
#      '240': 'https://img.hhcdn.ru/employer-logo/7267705.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11920587',
#     'country_id': 1,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Владение Python и основными библиотеками анализа данных. Знание SQL (оконные функции, оптимизация запросов) и навыки работы с базами данных. ',
#     'responsibility': 'Заниматься построением и поддержкой скоринговых моделей, самостоятельно строить ML-модели (логистическая регрессия, градиентный бустинг, деревья решений) для прогноза дефолтов. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128586832',
#    'premium': False,
#    'name': 'Middle Data Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '160',
#     'name': 'Алматы',
#     'url': 'https://api.hh.ru/areas/160'},
#    'salary': {'from': 1400000,
#     'to': 1600000,
#     'currency': 'KZT',
#     'gross': False},
#    'salary_range': {'from': 1400000,
#     'to': 1600000,
#     'currency': 'KZT',
#     'gross': False,
#     'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#     'frequency': None},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Алматы',
#     'street': 'улица Абиша Кекилбайулы',
#     'building': '139',
#     'lat': 43.205491,
#     'lng': 76.889338,
#     'description': None,
#     'raw': 'Алматы, улица Абиша Кекилбайулы, 139',
#     'metro': None,
#     'metro_stations': [],
#     'id': '16586649'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-12-09T17:47:04+0300',
#    'created_at': '2025-12-09T17:47:04+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128586832',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128586832?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128586832',
#    'relations': [],
#    'employer': {'id': '10780378',
#     'name': 'Teez',
#     'url': 'https://api.hh.ru/employers/10780378',
#     'alternate_url': 'https://hh.ru/employer/10780378',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/6731961.jpeg',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/6731962.jpeg',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/6731963.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10780378',
#     'country_id': 3,
#     'accredited_it_employer': False,
#     'trusted': True},
#    'snippet': {'requirement': 'Быстро решили, быстро сделали, быстро поехали дальше. Опыт работы в <highlighttext>Data</highlighttext> Science от 2-х лет. Умение работать с SQL...',
#     'responsibility': 'Развивать самостоятельно систему поисковой выдачи для маркетплейса на базе ML-технологий (ранжирование, персонализация, векторный поиск и др). Создавать решения, упрощающие...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '165', 'name': 'Дата-сайентист'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None},
#   {'id': '128147364',
#    'premium': False,
#    'name': 'Исследователь/Research Scientist',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'salary_range': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Шлюзовая набережная',
#     'building': '4',
#     'lat': 55.731551,
#     'lng': 37.644261,
#     'description': None,
#     'raw': 'Москва, Шлюзовая набережная, 4',
#     'metro': {'station_name': 'Павелецкая',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.101',
#      'line_id': '2',
#      'lat': 55.729741,
#      'lng': 37.638693},
#     'metro_stations': [{'station_name': 'Павелецкая',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.101',
#       'line_id': '2',
#       'lat': 55.729741,
#       'lng': 37.638693},
#      {'station_name': 'Павелецкая',
#       'line_name': 'Кольцевая',
#       'station_id': '5.102',
#       'line_id': '5',
#       'lat': 55.731414,
#       'lng': 37.636294}],
#     'id': '2307678'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2025-11-27T17:20:09+0300',
#    'created_at': '2025-11-27T17:20:09+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128147364',
#    'show_logo_in_search': None,
#    'show_contacts': False,
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/128147364?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/128147364',
#    'relations': [],
#    'employer': {'id': '3491569',
#     'name': 'Криптонит',
#     'url': 'https://api.hh.ru/employers/3491569',
#     'alternate_url': 'https://hh.ru/employer/3491569',
#     'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/4016742.png',
#      '90': 'https://img.hhcdn.ru/employer-logo-round/4016743.png',
#      '240': 'https://img.hhcdn.ru/employer-logo-round/4016744.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3491569',
#     'country_id': 1,
#     'accredited_it_employer': True,
#     'trusted': True},
#    'snippet': {'requirement': 'Ученая степень, законченная аспирантура, наличие научных публикаций/докладов. Знание и уверенное владение минимум двумя языками программирования, знание современных Unix-style...',
#     'responsibility': 'Ведение исследовательских работ в области математики, Computer Science, электроники, телекоммуникаций и сетей, смежных областях.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False,
#    'fly_in_fly_out_duration': [],
#    'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#     {'id': 'HYBRID', 'name': 'Гибрид'}],
#    'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#    'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#    'night_shifts': False,
#    'professional_roles': [{'id': '79',
#      'name': 'Научный специалист, исследователь'}],
#    'accept_incomplete_resumes': False,
#    'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#    'employment': {'id': 'full', 'name': 'Полная занятость'},
#    'employment_form': {'id': 'FULL', 'name': 'Полная'},
#    'internship': False,
#    'adv_response_url': None,
#    'is_adv_vacancy': False,
#    'adv_context': None}],
#  'found': 387,
#  'pages': 78,
#  'page': 1,
#  'per_page': 5,
#  'clusters': None,
#  'arguments': None,
#  'fixes': None,
#  'suggests': None,
#  'alternate_url': 'https://hh.ru/search/vacancy?enable_snippets=true&items_on_page=5&page=1&text=Data+Scientist'}

# %% [markdown]
# Мы получили вакансии, как и запрашивали. Вот только теперь они лежат в словарях, которые нам предстоит разобрать. Описанипе всех тегов вы можете найти в документации.
#
# Итак, посмотрим, какие ключи есть в нашем словаре.

# %%
data.keys()
# Out:
# dict_keys(['items', 'found', 'pages', 'page', 'per_page', 'clusters', 'arguments', 'fixes', 'suggests', 'alternate_url'])

# %% [markdown]
# Здесь указаны параметры, которые мы передавали (относительно страниц и числа вакансий на них), а также прочие основные параметры. Но нас интересует только список с вакансиями, он лежит с ключом `items`.

# %%
len(data['items'])
# Out:
# 5

# %% [markdown]
# Тут мы оценили размер списка, лежащего под указанным ключом. В нём действительно 20 элементов, как мы и запрашивали. Посмотрим на первый.

# %%
data['items'][0]
# Out:
# {'id': '128921862',
#  'premium': False,
#  'name': 'Project Manager (AI)',
#  'department': None,
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1002',
#   'name': 'Минск',
#   'url': 'https://api.hh.ru/areas/1002'},
#  'salary': {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False},
#  'salary_range': {'from': 1118,
#   'to': 1615,
#   'currency': 'USD',
#   'gross': False,
#   'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#   'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': {'city': 'Минск',
#   'street': 'Национальный аэропорт Минск',
#   'building': None,
#   'lat': 53.889263,
#   'lng': 28.034156,
#   'description': None,
#   'raw': 'Минск, Национальный аэропорт Минск',
#   'metro': None,
#   'metro_stations': [],
#   'id': '13721893'},
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2025-12-19T17:50:24+0300',
#  'created_at': '2025-12-19T17:50:24+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128921862',
#  'show_logo_in_search': None,
#  'show_contacts': True,
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/128921862?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/128921862',
#  'relations': [],
#  'employer': {'id': '9228941',
#   'name': 'Up pashkevich',
#   'url': 'https://api.hh.ru/employers/9228941',
#   'alternate_url': 'https://hh.ru/employer/9228941',
#   'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/7007109.png',
#    '90': 'https://img.hhcdn.ru/employer-logo-round/7007110.png',
#    '240': 'https://img.hhcdn.ru/employer-logo-round/7007111.png'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9228941',
#   'country_id': 8,
#   'accredited_it_employer': False,
#   'trusted': True},
#  'snippet': {'requirement': 'Опыт в роли Project Manager от 1,5 лет, включая управление AI/ML-проектами. Подтверждённый опыт ведения полного цикла AI...',
#   'responsibility': 'Координация работы кросс-функциональной команды (ML-инженеры, <highlighttext>data</highlighttext> <highlighttext>scientists</highlighttext>, разработчики). Взаимодействие со стейкхолдерами, управление ожиданиями и коммуникацией. Оптимизация процессов разработки...'},
#  'contacts': None,
#  'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False,
#  'fly_in_fly_out_duration': [],
#  'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#  'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#  'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#  'night_shifts': False,
#  'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#  'accept_incomplete_resumes': False,
#  'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#  'employment': {'id': 'full', 'name': 'Полная занятость'},
#  'employment_form': {'id': 'FULL', 'name': 'Полная'},
#  'internship': False,
#  'adv_response_url': None,
#  'is_adv_vacancy': False,
#  'adv_context': None}

# %% [markdown]
# ## Параметры

# %% [markdown]
# Мы видим большое количество параметров, свойств, описание которых (подробное и на русском) есть в документации. Отсюда многое можно взять в нашу таблицу для анализа. Я возьму лишь пару параметров для демонстрации.

# %%
vacancy = data['items'][0]

# %%
vacancy['name']
# Out:
# 'Project Manager (AI)'

# %%
vacancy['id']
# Out:
# '128921862'

# %%
vacancy['salary']
# Out:
# {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False}

# %% [markdown]
# Вот тут могут начинаться первые проблемы. Данных о зарплате может и не быть вовсе, а могут быть неполные. Тут стоит обрабатывать данные аккуратно.
#
# Подберём две вакансии, одну с зарплатой, другую без, и посмотрим разницу.

# %%
# с зарплатой
vacancy_s = [v for v in data['items'] if v['salary']][0]
# без зарплаты
vacancy_w = [v for v in data['items'] if not v['salary']][0]

# %% [markdown]
# Дадите объяснение моим действиям? Если не очень понятно, то пустое значение `None` приравнивается к `False`, поэтому условие выглядит именно так. А как бы сделали вы?

# %%
vacancy_w['salary']

# %% [markdown]
# Тут и правда не указаны зарплаты. Что ж, посмотрим на вторую вакансию.

# %%
vacancy_s['salary']
# Out:
# {'from': 1118, 'to': 1615, 'currency': 'USD', 'gross': False}

# %% [markdown]
# Внутри не просто число, внутри лежит целый словарь (если что-то пошло не так, выгрузите список вакансий снова или увеличьте размер выгрузки, возможно, в этом нет вакансий с зарплатой). А в нём указаны границы зарплатной вилки, валюта и даже указание, до или после вычета налогов.
#
# Как бы вы поступили с такими данными? Я возьму только одно из значений - нижнюю границу зарплаты. Но это для демонстрации, ваше решение явно будет отличаться.

# %%
vacancy_s['salary']['from']
# Out:
# 1118

# %% [markdown]
# Это всё хорошо, но как же достать это значение, если этого словаря не будет вообще? Конечно, проверить на наличие. Давайте напишем небольшой цикл, пробежав по имеющимся у нас вакансиям.

# %%
for vacancy in data['items']:
    if vacancy['salary']:
        print(vacancy['salary']['from'])
    else:
        print('Не указано')
# Out:
# 1118
# Не указано
# Не указано
# 1400000
# Не указано

# %% [markdown]
# Сможем ли мы сократить это условие? Конечно, воспользуемся тернарным оператором:

# %%
for vacancy in data['items']:
    print(vacancy['salary']['from'] if vacancy['salary'] else 'Не указано')
# Out:
# 1118
# Не указано
# Не указано
# 1400000
# Не указано

# %% [markdown]
# Прекрасно! А главное, кратко и понятно.

# %% [markdown]
# ## Собираем таблицу

# %% [markdown]
# Попробуем создать небольшую таблицу для данных. Я создам совсем небольшую, чтобы посмотреть, как это работает.

# %%
df = pd.DataFrame(columns=['name', 'salary_from'])

for vacancy in data['items']:
    id = vacancy['id']
    name = vacancy['name']
    salary_from = vacancy['salary']['from'] if vacancy['salary'] else None
    df.loc[id] = [name, salary_from]

# %%
df
# Out:
#                                              name salary_from
# 128921862                    Project Manager (AI)        1118
# 128731045  Аналитик больших данных/Data Scientist        None
# 128544099                          Data Scientist        None
# 128586832                   Middle Data Scientist     1400000
# 128147364        Исследователь/Research Scientist        None

# %% [markdown]
# Да, табличка и правда получилась!
#
# Конечно, я оставил для вас самое интересное. Как минимум, примените бритву Оккама - тут слишком много лишних сущностей, можно и короче. А как максимум...

# %% [markdown]
# ## Парсим интересные вакансии

# %% [markdown]
# Как максимум я хочу, чтобы вы собрали большую таблицу по вакансиям и проанализировали её. При этом выберите ту должность, которая интересно лично вам.
#
# Предлагаю такие шаги:
#
# 1. Какие данные из вакансии заслуживают внимания? Что стоит доставать и помещать в таблицу? Уделите особое внимание численным параметрам - с остальными мы пока не особо учились работать.
# 2. Какие данные могут быть проблемными? Где-то могут встречаться пропуски, как в зарплатах, их нужно обработать.
# 3. Как собрать больше вакансий? Больше 100 на странице не получится, а страниц может быть несколько. Надо собрать данные со всех.
# 4. Какой базовый анализ можно провести? Интересно, какие зарплаты предлагают по должностям, в каких городах сколько вакансий, и прочее, прочее, прочее...
#
# Уверен, это не составит большого труда, у вас всё получится!

# %%
import requests, time

def get_vacancies_minimal(text="Data Scientist"):
    url = 'https://api.hh.ru/vacancies'
    results = []
    
    for page in range(5):
        response = requests.get(url, params={
            'text': text,
            'per_page': 100,
            'page': page
        }, headers={'User-Agent': 'TestBot'})
        
        if response.status_code == 200:
            data = response.json()
            if data.get('items'):
                results.extend(data['items'])
                print(f"Page {page}: {len(data['items'])} items")
            else:
                break
        time.sleep(0.3)
    
    print(f"Total: {len(results)} vacancies")
    return results

# %%
my_data = get_vacancies_minimal(text="web")
# Out:
# Page 0: 100 items
# Page 1: 100 items
# Page 2: 100 items
# Page 3: 100 items
# Page 4: 100 items
# Total: 500 vacancies
# [{'id': '128818364',
#   'premium': False,
#   'name': 'Веб разработчик',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '159',
#    'name': 'Астана',
#    'url': 'https://api.hh.ru/areas/159'},
#   'salary': {'from': 110000, 'to': None, 'currency': 'KZT', 'gross': True},
#   'salary_range': {'from': 110000,
#    'to': None,
#    'currency': 'KZT',
#    'gross': True,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': {'id': 'MONTHLY', 'name': 'Раз в\xa0месяц'}},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-17T10:44:40+0300',
#   'created_at': '2025-12-17T10:44:40+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128818364',
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128818364?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128818364',
#   'relations': [],
#   'employer': {'id': '11300317',
#    'name': 'REVEAL',
#    'url': 'https://api.hh.ru/employers/11300317',
#    'alternate_url': 'https://hh.ru/employer/11300317',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11300317',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Базовые знания HTML, CSS, JavaScript. Желание учиться и развиваться в сфере ИИ-разработки. Умение работать в команде и находить общий...',
#    'responsibility': 'Разработка и поддержка <highlighttext>веб</highlighttext>-приложений и сайтов. Интеграция с маркетплейсами для продажи ноутбуков. Оптимизация и улучшение пользовательского интерфейса. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128926701',
#   'premium': False,
#   'name': 'Frontend & Backend and AI Developer Internship/Junior Opportunities',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2759',
#    'name': 'Ташкент',
#    'url': 'https://api.hh.ru/areas/2759'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Ташкент',
#    'street': 'улица Фурката',
#    'building': '15/1',
#    'lat': 41.308313,
#    'lng': 69.24428,
#    'description': None,
#    'raw': 'Ташкент, улица Фурката, 15/1',
#    'metro': None,
#    'metro_stations': [],
#    'id': '18438891'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-20T15:24:37+0300',
#   'created_at': '2025-12-20T15:24:37+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128926701',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128926701?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128926701',
#   'relations': [],
#   'employer': {'id': '11233773',
#    'name': 'SATashkent',
#    'url': 'https://api.hh.ru/employers/11233773',
#    'alternate_url': 'https://hh.ru/employer/11233773',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/7156526.png',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/7156527.png',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/7156528.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11233773',
#    'country_id': 6,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'SATashkent is seeking motivated Frontend and Backend and AI Developer Interns for a 1-3 month internship. This position is...',
#    'responsibility': '...maintaining <highlighttext>web</highlighttext> applications using React.js. - Collaborate with designers and backend developers to implement features. - Create responsive and visually appealing <highlighttext>web</highlighttext>...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#     'name': 'Можно сменами по\xa04-6\xa0часов в\xa0день'}],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#   'working_hours': [{'id': 'HOURS_6', 'name': '6\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'SIX_ON_ONE_OFF', 'name': '6/1'}],
#   'night_shifts': True,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': True,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128790761',
#   'premium': False,
#   'name': 'Middle Frontend Engineer (React / Next.js)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2759',
#    'name': 'Ташкент',
#    'url': 'https://api.hh.ru/areas/2759'},
#   'salary': {'from': 10000000, 'to': None, 'currency': 'UZS', 'gross': False},
#   'salary_range': {'from': 10000000,
#    'to': None,
#    'currency': 'UZS',
#    'gross': False,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': None},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Ташкент',
#    'street': None,
#    'building': None,
#    'lat': 41.311144,
#    'lng': 69.279728,
#    'description': None,
#    'raw': 'Ташкент',
#    'metro': None,
#    'metro_stations': [],
#    'id': '21243088'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-16T16:19:48+0300',
#   'created_at': '2025-12-16T16:19:48+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128790761',
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128790761?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128790761',
#   'relations': [],
#   'employer': {'id': '9483162',
#    'name': 'Mukarrama Muallima',
#    'url': 'https://api.hh.ru/employers/9483162',
#    'alternate_url': 'https://hh.ru/employer/9483162',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9483162',
#    'country_id': 6,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт коммерческой разработки от 2–3 лет. Уверенное владение React и TypeScript. Опыт работы с Next.js. Практический опыт разработки B...',
#    'responsibility': 'Мы ищем Middle Frontend Engineer, который будет участвовать в разработке и развитии <highlighttext>Web</highlighttext>-интерфейсов B2B-продукта. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_7', 'name': '7 часов'}],
#   'work_schedule_by_days': [{'id': 'SIX_ON_ONE_OFF', 'name': '6/1'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128528809',
#   'premium': False,
#   'name': 'Технический специалист в сфере IT',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '181',
#    'name': 'Павлодар',
#    'url': 'https://api.hh.ru/areas/181'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-08T12:15:19+0300',
#   'created_at': '2025-12-08T12:15:19+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128528809',
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128528809?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128528809',
#   'relations': [],
#   'employer': {'id': '10496839',
#    'name': 'НАУЧНО-ИССЛЕДОВАТЕЛЬСКИЙ ЦЕНТР KAZAKHSTAN RESEARCH AND DEVEIOPMENT',
#    'url': 'https://api.hh.ru/employers/10496839',
#    'alternate_url': 'https://hh.ru/employer/10496839',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10496839',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Базовые навыки программирования (желательно Python) — приветствуются. Понимание основ работы <highlighttext>веб</highlighttext>-сервисов. Способность быстро разбираться в новых задачах. Ответственность, аккуратность и...',
#    'responsibility': 'Созданием и поддержкой внутренних программных инструментов. Автоматизацией рабочих процессов и документооборота. Участием в разработке новых сервисов для сотрудников. '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#    {'id': 'HYBRID', 'name': 'Гибрид'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '121',
#     'name': 'Специалист технической поддержки'}],
#   'accept_incomplete_resumes': True,
#   'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128743054',
#   'premium': False,
#   'name': 'Системный администратор',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': True,
#   'area': {'id': '159',
#    'name': 'Астана',
#    'url': 'https://api.hh.ru/areas/159'},
#   'salary': {'from': 500000, 'to': None, 'currency': 'KZT', 'gross': False},
#   'salary_range': {'from': 500000,
#    'to': None,
#    'currency': 'KZT',
#    'gross': False,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Астана',
#    'street': 'проспект Туран',
#    'building': '24',
#    'lat': 51.13836623733611,
#    'lng': 71.41193355587473,
#    'description': None,
#    'raw': 'Астана, проспект Туран, 24',
#    'metro': None,
#    'metro_stations': [],
#    'id': '21205305'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-15T11:42:48+0300',
#   'created_at': '2025-12-15T11:42:48+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128743054',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128743054?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128743054',
#   'relations': [],
#   'employer': {'id': '11258799',
#    'name': 'CAM Networks',
#    'url': 'https://api.hh.ru/employers/11258799',
#    'alternate_url': 'https://hh.ru/employer/11258799',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/6914921.jpeg',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/6914922.jpeg',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/6914923.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11258799',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Знание архитектуры современных операционных систем (Windows Server, Linux). Владение инструментами доменной инфраструктуры: Active Directory, DNS, DHCP, GPO, RDP. ',
#    'responsibility': 'Обеспечение бесперебойной работы серверного и сетевого оборудования. Мониторинг ИТ-инфраструктуры и оперативное устранение инцидентов и перебоев. Управление учетными записями и...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '113', 'name': 'Системный администратор'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128785462',
#   'premium': False,
#   'name': 'Frontend-разработчик',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2759',
#    'name': 'Ташкент',
#    'url': 'https://api.hh.ru/areas/2759'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-16T14:13:26+0300',
#   'created_at': '2025-12-16T14:13:26+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128785462',
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128785462?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128785462',
#   'relations': [],
#   'employer': {'id': '12502817',
#    'name': 'CODEREVIEW',
#    'url': 'https://api.hh.ru/employers/12502817',
#    'alternate_url': 'https://hh.ru/employer/12502817',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=12502817',
#    'country_id': 6,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт интеграции с backend на Laravel. Понимание Core <highlighttext>Web</highlighttext> Vitals и базовой оптимизации производительности. Опыт работы с TanStack Query / SWR. ',
#    'responsibility': 'Разработка и поддержка пользовательских интерфейсов для публичных сайтов и админ-панелей. Верстка страниц по дизайн-макетам (Figma) с соблюдением Pixel...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#     'name': 'Можно сменами по\xa04-6\xa0часов в\xa0день'}],
#   'working_time_modes': [],
#   'accept_temporary': True,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#    {'id': 'REMOTE', 'name': 'Удалённо'}],
#   'working_hours': [{'id': 'HOURS_4', 'name': '4\xa0часа'}],
#   'work_schedule_by_days': [{'id': 'OTHER', 'name': 'Другое'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#   'employment': {'id': 'project', 'name': 'Проектная работа'},
#   'employment_form': {'id': 'PROJECT', 'name': 'Проект'},
#   'internship': True,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128794602',
#   'premium': False,
#   'name': 'QA Engineer',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1004',
#    'name': 'Могилев',
#    'url': 'https://api.hh.ru/areas/1004'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-16T17:48:35+0300',
#   'created_at': '2025-12-16T17:48:35+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128794602',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128794602?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128794602',
#   'relations': [],
#   'employer': {'id': '2759395',
#    'name': 'СТЭКЛЭВЭЛ ГРУПП',
#    'url': 'https://api.hh.ru/employers/2759395',
#    'alternate_url': 'https://hh.ru/employer/2759395',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/3285343.jpeg',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/3285344.jpeg',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/3285345.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2759395',
#    'country_id': 4,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Hands-on experience in manual testing of <highlighttext>web</highlighttext> applications (functional, UI, regression, smoke testing). Experience with BrowserStack for cross-browser...',
#    'responsibility': 'Confident work with Jira: creating bug reports, test cases, test runs, and managing task statuses. Strong bug reporting skills: clear...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128898599',
#   'premium': False,
#   'name': 'Технический Директор',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '2760',
#    'name': 'Бишкек',
#    'url': 'https://api.hh.ru/areas/2760'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Бишкек',
#    'street': 'улица Раззакова',
#    'building': '19',
#    'lat': 42.868569,
#    'lng': 74.604429,
#    'description': None,
#    'raw': 'Бишкек, улица Раззакова, 19',
#    'metro': None,
#    'metro_stations': [],
#    'id': '21298131'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-19T14:33:13+0300',
#   'created_at': '2025-12-19T14:33:13+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128898599',
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128898599?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128898599',
#   'relations': [],
#   'employer': {'id': '12508355',
#    'name': 'ОАО Процессинг КейДжи',
#    'url': 'https://api.hh.ru/employers/12508355',
#    'alternate_url': 'https://hh.ru/employer/12508355',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=12508355',
#    'country_id': 7,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт запуска интеграций в сфере финтех (API и пр. технологии), понимание архитектуры <highlighttext>веб</highlighttext>-приложений, жизненного цикла данных, основ ИБ. ',
#    'responsibility': 'Управление IT-проектами полного цикла по внедрению, разработке и доработке банковских систем; управление рисками, изменениями и ожиданиями. Выполнение роли бизнес...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': True,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '125', 'name': 'Технический директор (CTO)'}],
#   'accept_incomplete_resumes': True,
#   'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128744268',
#   'premium': False,
#   'name': 'Начальник отдела маркетинга',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-15T12:02:00+0300',
#   'created_at': '2025-12-15T12:02:00+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128744268',
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128744268?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128744268',
#   'relations': [],
#   'employer': {'id': '3068675',
#    'name': 'WF Group',
#    'url': 'https://api.hh.ru/employers/3068675',
#    'alternate_url': 'https://hh.ru/employer/3068675',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3068675',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Подтверждённый успешный опыт стратегического планирования и запуска новых продуктов. Знание инструментов <highlighttext>веб</highlighttext>-аналитики, SEO/SEM, E-commerce, основ работы с...',
#    'responsibility': 'Цифровой маркетинг и E-commerce: Курирование и развитие корпоративного <highlighttext>веб</highlighttext>-сайта (оптимизация, контент, лидогенерация). Организация и контроль продаж в маркетплейсах...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '170',
#     'name': 'Руководитель отдела маркетинга и рекламы'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'moreThan6', 'name': 'Более 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128726849',
#   'premium': False,
#   'name': 'Backend-стажер (Python)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-14T22:24:46+0300',
#   'created_at': '2025-12-14T22:24:46+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128726849',
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128726849?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128726849',
#   'relations': [],
#   'employer': {'id': '11746270',
#    'name': 'Стади Ниндзя',
#    'url': 'https://api.hh.ru/employers/11746270',
#    'alternate_url': 'https://hh.ru/employer/11746270',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=11746270',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Инфраструктура: Docker, Git, CI/CD. AI/ML: OpenAI API, знакомство с архитектурами агентов. Понимает основы Python 3 и имеет небольшой...',
#    'responsibility': 'В твои задачи будет входить: Разработка и поддержка API на FastAPI для <highlighttext>веб</highlighttext>-приложений и сервисов. Работа с бизнес-логикой...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [{'id': 'from_four_to_six_hours_in_a_day',
#     'name': 'Можно сменами по\xa04-6\xa0часов в\xa0день'}],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#   'working_hours': [{'id': 'HOURS_4', 'name': '4\xa0часа'},
#    {'id': 'HOURS_8', 'name': '8\xa0часов'},
#    {'id': 'FLEXIBLE', 'name': 'По\xa0договорённости'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'},
#    {'id': 'WEEKEND', 'name': 'По\xa0выходным'},
#    {'id': 'FLEXIBLE', 'name': 'Свободный'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '40', 'name': 'Другое'}],
#   'accept_incomplete_resumes': True,
#   'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#   'employment': {'id': 'part', 'name': 'Частичная занятость'},
#   'employment_form': {'id': 'PART', 'name': 'Частичная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128493010',
#   'premium': False,
#   'name': 'Product Owner eCommerce продуктов (FoodTech)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Большие Каменщики',
#    'building': '9сЕ',
#    'lat': 55.738074,
#    'lng': 37.656047,
#    'description': None,
#    'raw': 'Москва, улица Большие Каменщики, 9сЕ',
#    'metro': {'station_name': 'Таганская',
#     'line_name': 'Таганско-Краснопресненская',
#     'station_id': '7.77',
#     'line_id': '7',
#     'lat': 55.739502,
#     'lng': 37.653605},
#    'metro_stations': [{'station_name': 'Таганская',
#      'line_name': 'Таганско-Краснопресненская',
#      'station_id': '7.77',
#      'line_id': '7',
#      'lat': 55.739502,
#      'lng': 37.653605}],
#    'id': '6529890'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-05T17:43:06+0300',
#   'created_at': '2025-12-05T17:43:06+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128493010',
#   'show_logo_in_search': None,
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128493010?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128493010',
#   'relations': [],
#   'employer': {'id': '3904785',
#    'name': 'Много лосося',
#    'url': 'https://api.hh.ru/employers/3904785',
#    'alternate_url': 'https://hh.ru/employer/3904785',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/5941236.jpeg',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/5941237.jpeg',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/5941238.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3904785',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Python и/или JavaScript на базовом уровне. Понимание, как работают <highlighttext>веб</highlighttext> приложения и HTTP API. Владение Postman, Insomnia или другим...',
#    'responsibility': 'ECommerce продуктами, включая клиентское мобильное приложение, сайт, программу лояльности, механики персонализации. В будущем возможно участие во внутренних продуктах - автодиспатч, автозаказ...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#    {'id': 'REMOTE', 'name': 'Удалённо'},
#    {'id': 'HYBRID', 'name': 'Гибрид'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '73', 'name': 'Менеджер продукта'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128144541',
#   'premium': False,
#   'name': 'Тестировщик ПО',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Ленинградское шоссе',
#    'building': '16Ас3',
#    'lat': 55.822291,
#    'lng': 37.499516,
#    'description': None,
#    'raw': 'Москва, Ленинградское шоссе, 16Ас3',
#    'metro': None,
#    'metro_stations': [],
#    'id': '15333040'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-11-27T16:15:56+0300',
#   'created_at': '2025-11-27T16:15:56+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128144541',
#   'show_logo_in_search': None,
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128144541?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128144541',
#   'relations': [],
#   'employer': {'id': '4360770',
#    'name': 'Наймикс',
#    'url': 'https://api.hh.ru/employers/4360770',
#    'alternate_url': 'https://hh.ru/employer/4360770',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/5781591.png',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/5781592.png',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/5781593.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4360770',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Знание хотя бы одного языка запросов (SQL базовый). Опыт тестирования <highlighttext>веб</highlighttext>- и/или мобильных приложений. Понимание Agile/Scrum. ',
#    'responsibility': 'Анализ требований: изучение бизнес-требований и технической документации; уточнение некорректных или неполных требований. Подготовка тестовой документации: составление тест-планов, чек...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'HYBRID', 'name': 'Гибрид'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128908741',
#   'premium': False,
#   'name': 'QA engineer manual',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': True,
#   'area': {'id': '5291',
#    'name': 'Лорино (Чукотский АО)',
#    'url': 'https://api.hh.ru/areas/5291'},
#   'salary': {'from': 100000, 'to': 220000, 'currency': 'RUR', 'gross': False},
#   'salary_range': {'from': 100000,
#    'to': 220000,
#    'currency': 'RUR',
#    'gross': False,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': {'id': 'MONTHLY', 'name': 'Раз в\xa0месяц'}},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'улица Охотный Ряд',
#    'building': None,
#    'lat': 55.757536,
#    'lng': 37.616414,
#    'description': None,
#    'raw': 'Москва, улица Охотный Ряд',
#    'metro': {'station_name': 'Охотный ряд',
#     'line_name': 'Сокольническая',
#     'station_id': '1.98',
#     'line_id': '1',
#     'lat': 55.757228,
#     'lng': 37.615078},
#    'metro_stations': [{'station_name': 'Охотный ряд',
#      'line_name': 'Сокольническая',
#      'station_id': '1.98',
#      'line_id': '1',
#      'lat': 55.757228,
#      'lng': 37.615078}],
#    'id': '14798830'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-19T11:23:20+0300',
#   'created_at': '2025-12-19T11:23:20+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128908741',
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128908741?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128908741',
#   'relations': [],
#   'employer': {'id': '9024989',
#    'name': 'Хантфлоу интграция УЗ1',
#    'url': 'https://api.hh.ru/employers/9024989',
#    'alternate_url': 'https://hh.ru/employer/9024989',
#    'logo_urls': None,
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=9024989',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы с системами контроля версий. -Опыт тестирования <highlighttext>web</highlighttext>-приложений и сервисов (frontend & backend). -Аналитический склад ума, внимательность к деталям. -',
#    'responsibility': 'Проведение ручного тестирования ПО. -Оформление дефектов в баг-трекинговой системе. -Разработка документации по тестированию (тест-планы и тест-кейсы). -'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128270538',
#   'premium': False,
#   'name': 'Делопроизводитель',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': None, 'to': 120000, 'currency': 'RUR', 'gross': False},
#   'salary_range': {'from': None,
#    'to': 120000,
#    'currency': 'RUR',
#    'gross': False,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Пресненская набережная',
#    'building': '8с1',
#    'lat': 55.747115,
#    'lng': 37.539078,
#    'description': None,
#    'raw': 'Москва, Пресненская набережная, 8с1',
#    'metro': {'station_name': 'Деловой центр',
#     'line_name': 'Большая кольцевая линия',
#     'station_id': '97.603',
#     'line_id': '97',
#     'lat': 55.7491,
#     'lng': 37.5395},
#    'metro_stations': [{'station_name': 'Деловой центр',
#      'line_name': 'Большая кольцевая линия',
#      'station_id': '97.603',
#      'line_id': '97',
#      'lat': 55.7491,
#      'lng': 37.5395},
#     {'station_name': 'Деловой центр',
#      'line_name': 'Солнцевская',
#      'station_id': '133.468',
#      'line_id': '133',
#      'lat': 55.7491,
#      'lng': 37.5395},
#     {'station_name': 'Москва-Сити',
#      'line_name': 'Филевская',
#      'station_id': '4.179',
#      'line_id': '4',
#      'lat': 55.748056,
#      'lng': 37.532778}],
#    'id': '4489877'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-01T15:25:26+0300',
#   'created_at': '2025-12-01T15:25:26+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128270538',
#   'show_logo_in_search': None,
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128270538?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128270538',
#   'relations': [],
#   'employer': {'id': '626837',
#    'name': 'Extyl',
#    'url': 'https://api.hh.ru/employers/626837',
#    'alternate_url': 'https://hh.ru/employer/626837',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/4010642.png',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/4010643.png',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/4010644.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=626837',
#    'country_id': 1,
#    'accredited_it_employer': True,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт на аналогичной позиции от 1 года. Грамотность, аккуратность и внимательность. Высокий уровень самоорганизации. Умение работать в режиме многозадачности. ',
#    'responsibility': 'По нагрузке: примерно 50% делопроизводство и 50% секретарские задачи. Ведение бумажного и электронного документооборота. Отслеживание своевременного рассмотрения и подписания документов...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': True,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '33',
#     'name': 'Делопроизводитель, архивариус'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '127513656',
#   'premium': False,
#   'name': 'Контент-менеджер',
#   'department': {'id': '866666-866666-market', 'name': 'BetBoom.Маркетинг'},
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': 'Ленинградский проспект',
#    'building': '37Ак4',
#    'lat': 55.791734,
#    'lng': 37.542419,
#    'description': None,
#    'raw': 'Москва, Ленинградский проспект, 37Ак4',
#    'metro': {'station_name': 'Аэропорт',
#     'line_name': 'Замоскворецкая',
#     'station_id': '2.12',
#     'line_id': '2',
#     'lat': 55.800441,
#     'lng': 37.530477},
#    'metro_stations': [{'station_name': 'Аэропорт',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.12',
#      'line_id': '2',
#      'lat': 55.800441,
#      'lng': 37.530477},
#     {'station_name': 'Динамо',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.34',
#      'line_id': '2',
#      'lat': 55.789704,
#      'lng': 37.558212},
#     {'station_name': 'Петровский парк',
#      'line_name': 'Большая кольцевая линия',
#      'station_id': '97.599',
#      'line_id': '97',
#      'lat': 55.79233,
#      'lng': 37.55952},
#     {'station_name': 'ЦСКА',
#      'line_name': 'Большая кольцевая линия',
#      'station_id': '97.600',
#      'line_id': '97',
#      'lat': 55.78643,
#      'lng': 37.53502}],
#    'id': '19330029'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-11-24T13:29:14+0300',
#   'created_at': '2025-11-24T13:29:14+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=127513656',
#   'branding': {'type': 'MAKEUP', 'tariff': None},
#   'show_logo_in_search': True,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/127513656?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/127513656',
#   'relations': [],
#   'employer': {'id': '866666',
#    'name': 'BetBoom',
#    'url': 'https://api.hh.ru/employers/866666',
#    'alternate_url': 'https://hh.ru/employer/866666',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/3480508.png',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/3480509.png',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/3480510.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=866666',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы в маркетинге от 2-х лет. Любовь и высокая погруженность в спорт, киберспорт и казино тематику. ',
#    'responsibility': 'Координировать разработку контента для сайтов компании, страниц амбассадоров, презентаций, <highlighttext>веб</highlighttext>-материалов (вижуалы, лендинги, страницы акций, промоматериалы, email и прочее). '},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '3',
#     'name': 'SMM-менеджер, контент-менеджер'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128815152',
#   'premium': False,
#   'name': 'Стажер/UI/UX дизайнер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': {'from': None, 'to': 180000, 'currency': 'KZT', 'gross': True},
#   'salary_range': {'from': None,
#    'to': 180000,
#    'currency': 'KZT',
#    'gross': True,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': None},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Алматы',
#    'street': 'проспект Достык',
#    'building': '38',
#    'lat': 43.252333,
#    'lng': 76.956937,
#    'description': None,
#    'raw': 'Алматы, проспект Достык, 38',
#    'metro': {'station_name': 'Абая',
#     'line_name': 'Первая',
#     'station_id': '64.433',
#     'line_id': '64',
#     'lat': 43.242548,
#     'lng': 76.949588},
#    'metro_stations': [{'station_name': 'Абая',
#      'line_name': 'Первая',
#      'station_id': '64.433',
#      'line_id': '64',
#      'lat': 43.242548,
#      'lng': 76.949588},
#     {'station_name': 'Алмалы',
#      'line_name': 'Первая',
#      'station_id': '64.432',
#      'line_id': '64',
#      'lat': 43.251295,
#      'lng': 76.945456},
#     {'station_name': 'Жибек Жолы',
#      'line_name': 'Первая',
#      'station_id': '64.431',
#      'line_id': '64',
#      'lat': 43.260199,
#      'lng': 76.946103},
#     {'station_name': 'Райымбек батыра',
#      'line_name': 'Первая',
#      'station_id': '64.430',
#      'line_id': '64',
#      'lat': 43.271201,
#      'lng': 76.9448}],
#    'id': '20179195'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-17T09:51:42+0300',
#   'created_at': '2025-12-17T09:51:42+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128815152',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128815152?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128815152',
#   'relations': [],
#   'employer': {'id': '31453',
#    'name': 'AIR ASTANA, АО',
#    'url': 'https://api.hh.ru/employers/31453',
#    'alternate_url': 'https://hh.ru/employer/31453',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1429855.png',
#     '90': 'https://img.hhcdn.ru/employer-logo/7339069.png',
#     '240': 'https://img.hhcdn.ru/employer-logo/7339070.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=31453',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Имеет навыки работы с Figma или аналогичными дизайн-инструментами. Понимает основы визуального дизайна: сетки, типографику, иерархию, цвет. Имеет портфолио (учебные...',
#    'responsibility': 'Участие в разработке пользовательских интерфейсов для <highlighttext>веб</highlighttext>- и мобильных продуктов Air Astana. Работа с визуальной частью интерфейсов: композиция, типографика, цвета...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '34', 'name': 'Дизайнер, художник'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'noExperience', 'name': 'Нет опыта'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': True,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128741958',
#   'premium': False,
#   'name': 'Дизайнер',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': {'from': None, 'to': 600000, 'currency': 'KZT', 'gross': False},
#   'salary_range': {'from': None,
#    'to': 600000,
#    'currency': 'KZT',
#    'gross': False,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Алматы',
#    'street': 'Медеуский район, улица Козыбаева',
#    'building': '212',
# ...
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128103034',
#   'premium': False,
#   'name': 'UX/UI Designer (Junior +)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': True,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': {'from': 200000, 'to': None, 'currency': 'KZT', 'gross': False},
#   'salary_range': {'from': 200000,
#    'to': None,
#    'currency': 'KZT',
#    'gross': False,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': None},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-11-26T19:17:56+0300',
#   'created_at': '2025-11-26T19:17:56+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128103034',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128103034?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128103034',
#   'relations': [],
#   'employer': {'id': '10554966',
#    'name': 'ARC TEACH',
#    'url': 'https://api.hh.ru/employers/10554966',
#    'alternate_url': 'https://hh.ru/employer/10554966',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/6413096.jpeg',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/6413097.jpeg',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/6413098.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=10554966',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Уверенное знание фигмы. Основы дизайна. Трудолюбие. Исполнительность.',
#    'responsibility': 'Работа оффлайн, в Алматы тоже. Работа по правкам. Оффлайн встречи.'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '34', 'name': 'Дизайнер, художник'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128433725',
#   'premium': False,
#   'name': 'Тестировщик (QA инженер)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '4',
#    'name': 'Новосибирск',
#    'url': 'https://api.hh.ru/areas/4'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Новосибирск',
#    'street': 'улица Ломоносова',
#    'building': '53/1',
#    'lat': 55.039863,
#    'lng': 82.9358,
#    'description': None,
#    'raw': 'Новосибирск, улица Ломоносова, 53/1',
#    'metro': {'station_name': 'Маршала Покрышкина',
#     'line_name': 'Дзержинская',
#     'station_id': '53.304',
#     'line_id': '53',
#     'lat': 55.043634,
#     'lng': 82.935566},
#    'metro_stations': [{'station_name': 'Маршала Покрышкина',
#      'line_name': 'Дзержинская',
#      'station_id': '53.304',
#      'line_id': '53',
#      'lat': 55.043634,
#      'lng': 82.935566}],
#    'id': '2792399'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-04T14:13:28+0300',
#   'created_at': '2025-12-04T14:13:28+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128433725',
#   'branding': {'type': 'MAKEUP', 'tariff': None},
#   'show_logo_in_search': True,
#   'show_contacts': True,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128433725?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128433725',
#   'relations': [],
#   'employer': {'id': '706928',
#    'name': 'НЛ Континент',
#    'url': 'https://api.hh.ru/employers/706928',
#    'alternate_url': 'https://hh.ru/employer/706928',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1389591.png',
#     '90': 'https://img.hhcdn.ru/employer-logo/7178151.png',
#     '240': 'https://img.hhcdn.ru/employer-logo/7178152.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=706928',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Опыт работы в ручном тестировании (<highlighttext>web</highlighttext>, mobile, backend) от 2 лет. Теория тестирования. Понимание основных видов тестирования и принципов тест...',
#    'responsibility': 'Проведение всего цикла тестирования для <highlighttext>веб</highlighttext>- и мобильных приложений: от анализа требований до приемки. Тестирование нового функционала, regression-тестирование, sanity...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'},
#    {'id': 'REMOTE', 'name': 'Удалённо'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '124', 'name': 'Тестировщик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128771369',
#   'premium': False,
#   'name': 'Customer Success Manager (IT-проекты)',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#   'salary': {'from': 170000, 'to': 250000, 'currency': 'RUR', 'gross': True},
#   'salary_range': {'from': 170000,
#    'to': 250000,
#    'currency': 'RUR',
#    'gross': True,
#    'mode': {'id': 'MONTH', 'name': 'За\xa0месяц'},
#    'frequency': {'id': 'TWICE_PER_MONTH', 'name': 'Два раза в\xa0месяц'}},
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': {'city': 'Москва',
#    'street': None,
#    'building': None,
#    'lat': 55.755864,
#    'lng': 37.617698,
#    'description': None,
#    'raw': 'Москва',
#    'metro': {'station_name': 'Библиотека им.Ленина',
#     'line_name': 'Сокольническая',
#     'station_id': '1.4',
#     'line_id': '1',
#     'lat': 55.752123,
#     'lng': 37.610388},
#    'metro_stations': [{'station_name': 'Библиотека им.Ленина',
#      'line_name': 'Сокольническая',
#      'station_id': '1.4',
#      'line_id': '1',
#      'lat': 55.752123,
#      'lng': 37.610388},
#     {'station_name': 'Охотный ряд',
#      'line_name': 'Сокольническая',
#      'station_id': '1.98',
#      'line_id': '1',
#      'lat': 55.757228,
#      'lng': 37.615078},
#     {'station_name': 'Площадь Революции',
#      'line_name': 'Арбатско-Покровская',
#      'station_id': '3.100',
#      'line_id': '3',
#      'lat': 55.756741,
#      'lng': 37.62236},
#     {'station_name': 'Театральная',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.99',
#      'line_id': '2',
#      'lat': 55.758808,
#      'lng': 37.61768}],
#    'id': '21230244'},
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-19T09:19:29+0300',
#   'created_at': '2025-12-19T09:19:29+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128771369',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128771369?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128771369',
#   'relations': [],
#   'employer': {'id': '2120662',
#    'name': 'Pimax',
#    'url': 'https://api.hh.ru/employers/2120662',
#    'alternate_url': 'https://hh.ru/employer/2120662',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original/1446932.png',
#     '90': 'https://img.hhcdn.ru/employer-logo/7407352.png',
#     '240': 'https://img.hhcdn.ru/employer-logo/7407353.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2120662',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Навыки структурирования информации и фиксации договорённостей. Понимание принципов <highlighttext>веб</highlighttext>-разработки и архитектуры приложений. Базовое понимание API, интеграций, баз данных, очередей...',
#    'responsibility': 'Быть единой точкой входа для ключевого клиента. Вести всю внешнюю коммуникацию с заказчиком по проектам. Участвовать в рабочих созвонах и...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128642768',
#   'premium': False,
#   'name': 'Frontend-разработчик (Vue.js) - Казахстан',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-10T20:53:05+0300',
#   'created_at': '2025-12-10T20:53:05+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128642768',
#   'show_logo_in_search': None,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128642768?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128642768',
#   'relations': [],
#   'employer': {'id': '5039006',
#    'name': 'Спортематика',
#    'url': 'https://api.hh.ru/employers/5039006',
#    'alternate_url': 'https://hh.ru/employer/5039006',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/6847393.png',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/6847394.png',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/6847395.png'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5039006',
#    'country_id': 1,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Отличные знания и опыт работы с JavaScript, Bootstrap, НТМL, СSS, SCSS, ЕS6+. — Vue 3 — composition АРI. — ',
#    'responsibility': 'Saas решение для управление профессиональных команд и спортсменов, как и уникальные проекты для клубов различных видов спорта. Разработка <highlighttext>веб</highlighttext> приложений...'},
#   'contacts': None,
#   'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': True,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'REMOTE', 'name': 'Удалённо'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '96', 'name': 'Программист, разработчик'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between3And6', 'name': 'От 3 до 6 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None},
#  {'id': '128747851',
#   'premium': False,
#   'name': 'Менеджер по ИТ проектам',
#   'department': None,
#   'has_test': False,
#   'response_letter_required': False,
#   'area': {'id': '160',
#    'name': 'Алматы',
#    'url': 'https://api.hh.ru/areas/160'},
#   'salary': None,
#   'salary_range': None,
#   'type': {'id': 'open', 'name': 'Открытая'},
#   'address': None,
#   'response_url': None,
#   'sort_point_distance': None,
#   'published_at': '2025-12-15T13:08:46+0300',
#   'created_at': '2025-12-15T13:08:46+0300',
#   'archived': False,
#   'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=128747851',
#   'branding': {'type': 'MAKEUP', 'tariff': None},
#   'show_logo_in_search': True,
#   'show_contacts': False,
#   'insider_interview': None,
#   'url': 'https://api.hh.ru/vacancies/128747851?host=hh.ru',
#   'alternate_url': 'https://hh.ru/vacancy/128747851',
#   'relations': [],
#   'employer': {'id': '34509',
#    'name': 'Carlsberg Kazakhstan',
#    'url': 'https://api.hh.ru/employers/34509',
#    'alternate_url': 'https://hh.ru/employer/34509',
#    'logo_urls': {'original': 'https://img.hhcdn.ru/employer-logo-original-round/579874.jpeg',
#     '90': 'https://img.hhcdn.ru/employer-logo-round/579875.jpeg',
#     '240': 'https://img.hhcdn.ru/employer-logo-round/579876.jpeg'},
#    'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=34509',
#    'country_id': 3,
#    'accredited_it_employer': False,
#    'trusted': True},
#   'snippet': {'requirement': 'Понимание и опыт работы с программным обеспечением и <highlighttext>веб</highlighttext>-технологиями. Отличные коммуникативные и организационные навыки, а также наличие сертификатов PMP...',
#    'responsibility': 'Планирование и координация ИТ-проектов. Управление проектными командами. Разработка и поддержка документации. Контроль бюджета и ресурсов. Взаимодействие с внутренними клиентами...'},
#   'contacts': None,
#   'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#   'working_days': [],
#   'working_time_intervals': [],
#   'working_time_modes': [],
#   'accept_temporary': False,
#   'fly_in_fly_out_duration': [],
#   'work_format': [{'id': 'ON_SITE', 'name': 'На\xa0месте работодателя'}],
#   'working_hours': [{'id': 'HOURS_8', 'name': '8\xa0часов'}],
#   'work_schedule_by_days': [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'},
#    {'id': 'FLEXIBLE', 'name': 'Свободный'}],
#   'night_shifts': False,
#   'professional_roles': [{'id': '107', 'name': 'Руководитель проектов'}],
#   'accept_incomplete_resumes': False,
#   'experience': {'id': 'between1And3', 'name': 'От 1 года до 3 лет'},
#   'employment': {'id': 'full', 'name': 'Полная занятость'},
#   'employment_form': {'id': 'FULL', 'name': 'Полная'},
#   'internship': False,
#   'adv_response_url': None,
#   'is_adv_vacancy': False,
#   'adv_context': None}]

# %% [markdown]
# # Data scientist Job

# %%
import requests
import time

def get_vacancies():
    url = 'https://api.hh.ru/vacancies'
    jsons_list = []
    
    headers = {'User-Agent': 'TestBot'}
    
    # Data Scientist с хорошей зарплатой, удалённо
    params = {
        'text': 'Data Scientist',
        'per_page': '100',
        'page': 0,
        'only_with_salary': True,
        'schedule': 'remote',
        'salary': 150000,
        'currency': 'RUR',
        'search_field': 'name',
        'order_by': 'salary_desc',
        'experience': 'between3And6',
    }
    

    for num_page in range(5):
        params['page'] = num_page
        
        try:
            src = requests.get(url, params=params, headers=headers, timeout=10)
            
            if src.status_code != 200:
                print(f"Страница {num_page}: Ошибка {src.status_code}")
                break
                
            data = src.json()
            
            if 'items' not in data or not data['items']:
                print(f"Страница {num_page}: больше нет вакансий")
                break
                
            jsons_list.append(data)
            print(f"Страница {num_page+1}: {len(data['items'])} вакансий")
            
            # pause api to fix timeout
            time.sleep(0.3)
            
        except requests.exceptions.Timeout:
            print(f"Страница {num_page}: Таймаут, пропускаем")
            continue
        except Exception as e:
            print(f"Страница {num_page}: Ошибка {type(e).__name__}")
            break
    
    print(f"\nСобрано: {len(jsons_list)} страниц с вакансиями")
    if jsons_list:
        total_vacancies = sum(len(page['items']) for page in jsons_list)
        print(f"Всего вакансий: {total_vacancies}")
        
        # gold_job
        if jsons_list[0]['items']:
            top_vacancy = jsons_list[0]['items'][0]
            salary = top_vacancy.get('salary', {})
            print(f"gold_job: {top_vacancy['name']}")
            print(f"   coin: {salary.get('from', '?')} - {salary.get('to', '?')} {salary.get('currency', 'руб.')}")
            if 'schedule' in top_vacancy:
                print(f"   График: {top_vacancy['schedule'].get('name', '?')}")
    
    return jsons_list

# %%
vacancies = get_vacancies()
# Out:
# Страница 1: 10 вакансий
# Страница 1: больше нет вакансий
#
# Собрано: 1 страниц с вакансиями
# Всего вакансий: 10
# gold_job: Lead Data Scientist (LLM) / Ведущий специалист по данным
#    coin: None - 5000 USD
#    График: Удаленная работа

# %% [markdown]
# # Job Table

# %%
import pandas as pd

data = pd.DataFrame(columns=[
    'title',               # Название
    'salary_min',          # ЗП от
    'salary_max',          # ЗП до  
    'experience',          # Опыт 3-6
    'company',             # Компания
    'location',            # Локация
    'work_schedule',       # График = удаленка
    'remote_type',         # Формат
    'key_requirements',    # Ключевые требования
    'is_trusted_employer', # Проверенный работодатель
    'has_test',            # Тест!
    'url'                  # Ссылка
])

for col in data.columns:
    print(f"  -> {col}")
# Out:
#   -> title
#   -> salary_min
#   -> salary_max
#   -> experience
#   -> company
#   -> location
#   -> work_schedule
#   -> remote_type
#   -> key_requirements
#   -> is_trusted_employer
#   -> has_test
#   -> url

# %%
for page in vacancies:
    if 'items' not in page:
        continue
        
    for vacancy in page['items']:
        row = {
            'title': vacancy.get('name', ''),
            'url': vacancy.get('alternate_url', ''),
        }
        
        salary_data = vacancy.get('salary')
        if salary_data:
            row['salary_min'] = salary_data.get('from')
            row['salary_max'] = salary_data.get('to')
        else:
            row['salary_min'] = None
            row['salary_max'] = None
        
        experience_data = vacancy.get('experience', {})
        row['experience'] = experience_data.get('name', '') if experience_data else ''
        
        employer_data = vacancy.get('employer', {})
        row['company'] = employer_data.get('name', '')
        row['is_trusted_employer'] = employer_data.get('trusted', False)
        
        area_data = vacancy.get('area', {})
        row['location'] = area_data.get('name', '')
        
        schedule_data = vacancy.get('schedule', {})
        row['work_schedule'] = schedule_data.get('name', '')
        
        work_format_data = vacancy.get('work_format', [{}])
        row['remote_type'] = work_format_data[0].get('name', '') if work_format_data else ''
        
        snippet_data = vacancy.get('snippet', {})
        requirements = snippet_data.get('requirement', '')
        row['key_requirements'] = requirements[:150] if requirements else ''
        
        row['has_test'] = vacancy.get('has_test', False)
        
        new_row_df = pd.DataFrame([row])
        data = pd.concat([data, new_row_df], ignore_index=True)

data
# Out:
#                                                title salary_min salary_max  \
# 0  Lead Data Scientist (LLM) / Ведущий специалист...       None       5000
# 1                         Senior ML / Data Scientist       3500       4350
# 2                            Data Scientist (senior)     200000     400000
# 3                            Data Scientist (senior)     200000     400000
# 4                            Data Scientist (senior)     200000     400000
# 5                            Data Scientist (senior)     200000     400000
# 6                            Data Scientist (senior)     200000     400000
# 7                                     Data Scientist       None     300000
# 8                      Data analyst / Data scientist     230000     250000
# 9                                     Data Scientist       None     180000
#
#       experience                   company         location     work_schedule  \
# 0  От 3 до 6 лет                WaveAccess  Санкт-Петербург  Удаленная работа
# 1  От 3 до 6 лет            ПБК Менеджмент            Минск  Удаленная работа
# 2  От 3 до 6 лет  Бюро судебного взыскания           Москва  Удаленная работа
# 3  От 3 до 6 лет  Бюро судебного взыскания           Казань  Удаленная работа
# 4  От 3 до 6 лет  Бюро судебного взыскания  Санкт-Петербург  Удаленная работа
# 5  От 3 до 6 лет  Бюро судебного взыскания     Екатеринбург  Удаленная работа
# 6  От 3 до 6 лет  Бюро судебного взыскания  Нижний Новгород  Удаленная работа
# 7  От 3 до 6 лет               Детский мир           Москва  Удаленная работа
# 8  От 3 до 6 лет                    ROSSKO           Москва  Удаленная работа
# 9  От 3 до 6 лет              Hawking Bros           Москва  Удаленная работа
#
#              remote_type                                   key_requirements  \
# 0               Удалённо  5+ years of commercial experience in <highligh...
# 1               Удалённо  Мы усиливаем команду разработки моделей и ищем...
# 2               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 3               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 4               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 5               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 6               Удалённо  Знание и опыт работы с очередями и брокерами с...
# 7  На месте работодателя  Уверенное владение знаниями о работе и создани...
# 8               Удалённо  Вы умеете выявлять факторы влияния на эффектив...
# 9               Удалённо  Опыт работы с табличными данными и классически...
#
#   is_trusted_employer has_test                              url
# 0                True    False  https://hh.ru/vacancy/128483349
# 1                True    False  https://hh.ru/vacancy/128152732
# 2                True    False  https://hh.ru/vacancy/127981401
# 3                True    False  https://hh.ru/vacancy/128913274
# 4                True    False  https://hh.ru/vacancy/128913275
# 5                True    False  https://hh.ru/vacancy/128913276
# 6                True    False  https://hh.ru/vacancy/128913277
# 7                True     True  https://hh.ru/vacancy/127795453
# 8                True    False  https://hh.ru/vacancy/127307468
# 9                True    False  https://hh.ru/vacancy/128102483

# %%
data.head(1)
# Out:
#                                                title salary_min salary_max  \
# 0  Lead Data Scientist (LLM) / Ведущий специалист...       None       5000
#
#       experience     company         location     work_schedule remote_type  \
# 0  От 3 до 6 лет  WaveAccess  Санкт-Петербург  Удаленная работа    Удалённо
#
#                                     key_requirements is_trusted_employer  \
# 0  5+ years of commercial experience in <highligh...                True
#
#   has_test                              url
# 0    False  https://hh.ru/vacancy/128483349

# %% [markdown]
# Lead Data Scientist (LLM) / Ведущий специалист по данным
#
# до 5 000 $ за месяц
#
# Формат работы: удалённо

# %%
data.iloc[0]['key_requirements']
# Out:
# '5+ years of commercial experience in <highlighttext>data</highlighttext> science or ML engineering. Ability to design the overall approach to solving.'

# %% [markdown]
# Виджет по api.hh.ru

# %%
from IPython.display import IFrame

# url
widget_url = "https://api.hh.ru/widgets/vacancies/employer?employer_id=2251053&locale=RU&links_color=1560b2&border_color=1560b2&title=&show_region=true&professional_role=165"

# widget
IFrame(src=widget_url, width=350, height=250)
